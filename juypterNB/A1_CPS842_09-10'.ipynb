# %% [markdown]
# Imports

# %%
from collections import OrderedDict
from bs4 import BeautifulSoup as bs

import numpy as np
import pandas as pd

import json
import gzip
import regex as re

import porterAlgo # Porter Stemming Algo

import spacy #python -m spacy download en_core_web_sm

class int64_encoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.int64):
            return int(obj)
        return json.JSONEncoder.default(self, obj)
        
#nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Stop Words
#
# - Using Cacm Stopwords txt file
# - https://github.com/AOikonomidis/collection-retrieval/blob/master/solr-config/cacm_configs/stopwords.txt

# %%
stopWords = []
with open("cacm_stopwords.txt","r") as stopWord:
    stopWords = [word.replace("\n","") for word in stopWord]

# %% [markdown]
# PorterStemming
#
# - Used porterAlgo.py to stem words (removes stop words, numbers, etc.)
# - Left numbers as is
# - removeNone(word) -> removes the word 'None' from the list results.
# - http://tartarus.org/~martin/PorterStemmer/

# %%
def porterStemming(uncleaned_word):
    porterStemming = porterAlgo.PorterStemmer()

    if uncleaned_word.isnumeric(): 
        return uncleaned_word # keep numbers as is
    
    word = re.sub('[^a-zA-Z]','',uncleaned_word) # remove special chars
    word_cleaned = porterStemming.stem(word,0,len(word)-1).lower().replace("\n","") #lemmatize token
    
    if word_cleaned not in stopWords and len(word_cleaned)>2: # remove stopwords
        return word_cleaned
    else: return 'None'
    
def removeNone(word):
    bad = ['None']
    if word in bad:
        return False
    return True

#porterStemming("pythonung78$_^(   )")

# %% [markdown]
# Dictionary File
#
# - Gets the document frequency for each term in the collection

# %%
#Term : Document Frequency
documentFrequency = {}

def docFrequency(docSet):
    for word in docSet:
        if word in documentFrequency: documentFrequency[word]+=1
        else: documentFrequency[word]=1

# %% [markdown]
# Context Window
# - How do we want to deal with the context windows?
# - We only need one which is good
# - Should be able to splice the doc tokens to get 5 to the left 5 to the right
# - What do we do if the word is the first/last in the doc?

# %%
def getWindow(size, index, doc):
  if index < size:
    window = doc[:index + size + 1]
  else:
    window = doc[index-size:index + size + 1]
  return window

# %% [markdown]
# Posting List
#
# - Updates postingListDict {word: {id: [doc freq, postings]}}
# - len(indexes) = term frequency
# - https://btechgeeks.com/python-how-to-find-all-indexes-of-an-item-in-a-list/#Using_Numpy

# %%
postingListDict = {}

def postingsList(set,id,doc):
    for word in set:
        indexes = np.where(np.array(doc) ==  word)[0] # finding all occurences of word
        indexes = list(indexes)
        contextWindow = " ".join(getWindow(5, indexes[0], doc))
        dict = {str(id):[len(indexes),indexes,contextWindow]}
        if word in postingListDict: # update main postingListDictionary
            postingListDict[word][str(id)] = [len(indexes), indexes,contextWindow]
        else:
            postingListDict[word]=dict

# %% [markdown]
# Process HTML
#
# - Deals with HTML within doc['contents']
# - Strips HTML code of all tags
# - contents_pretified = contents.prettify()
# - Stems content and returns it with id

# %%
def processContents(line):
     data=json.loads(line) # Load JSON
     id = data['id']
     title = data['title']

     contents = bs(data['contents'],"html.parser") #Deal with HTML content 

     contents_stripped=" ".join(contents.stripped_strings) # remove html tags from content
     contents_stripped = contents_stripped.split(" ")

     porterStem = list(map(porterStemming,contents_stripped)) # stem content
     porterStem = list(filter(removeNone,porterStem))

     return [id,porterStem]

# %% [markdown]
# Main
#
# - Run through gzip file (212651 files in gzip)
# - Start updating dictionary file and posting list

# %%
path  = "C:/Users/deand/OneDrive/Documents/CPS 842/trec_corpus_5000.jsonl.gz"
count = 0 # temporary

contentsPorterStemmed = []
with gzip.open(path,'rb') as file:

    for wiki in file:
        count+=1

        contents = processContents(wiki)
        wordsSet = set(contents[1])
        postingsList(wordsSet,contents[0],contents[1]) # Update Positing List
        docFrequency(wordsSet) # Update documentFrequency
       
        contentsPorterStemmed.append(contents)
    
        if count==30:break

# %%
postingListDict = OrderedDict(sorted(postingListDict.items())) #sorting dictionary
documentFrequency = OrderedDict(sorted(documentFrequency.items())) #sorting dictionary
postingListDict
# Out:
# OrderedDict([('0',
#               {'593630': [1, [332]],
#                1872229: [1, array([2674], dtype=int64)]}),
#              ('00',
#               {'1512303': [1, [1142]],
#                1512303: [1, array([1142], dtype=int64)]}),
#              ('007',
#               {'1512303': [50,
#                 [106,
#                  156,
#                  200,
#                  204,
#                  210,
#                  252,
#                  259,
#                  272,
#                  288,
#                  344,
#                  349,
#                  370,
#                  656,
#                  803,
#                  863,
#                  911,
#                  984,
#                  1068,
#                  1116,
#                  1159,
#                  1193,
#                  1197,
#                  1209,
#                  1326,
#                  1419,
#                  1425,
#                  1582,
#                  1596,
#                  1722,
#                  1796,
#                  1875,
#                  1937,
#                  1965,
#                  1991,
#                  1997,
#                  2008,
#                  2014,
#                  2027,
#                  2077,
#                  2093,
#                  2115,
#                  2411,
#                  2436,
#                  2564,
#                  2597,
#                  2600,
#                  2606,
#                  2629,
#                  2633,
#                  2637]],
#                1512303: [50,
#                 array([ 106,  156,  200,  204,  210,  252,  259,  272,  288,  344,  349,
#                         370,  656,  803,  863,  911,  984, 1068, 1116, 1159, 1193, 1197,
#                        1209, 1326, 1419, 1425, 1582, 1596, 1722, 1796, 1875, 1937, 1965,
#                        1991, 1997, 2008, 2014, 2027, 2077, 2093, 2115, 2411, 2436, 2564,
#                        2597, 2600, 2606, 2629, 2633, 2637], dtype=int64)]}),
#              ('0253207061', {'73423': [1, [776]]}),
#              ('0826429777', {'73423': [1, [1312]]}),
#              ('1',
#               {'1512303': [5, [49, 2018, 2024, 2032, 2108]],
#                67921406: [1, array([259], dtype=int64)],
#                1168659: [5, array([ 91, 521, 565, 598, 609], dtype=int64)],
#                706315: [8,
#                 array([ 503,  888, 1089, 1091, 1354, 1376, 1395, 1418], dtype=int64)],
#                6335141: [1, array([268], dtype=int64)],
#                1290848: [6,
#                 array([ 727, 1994, 2015, 2022, 2116, 3101], dtype=int64)],
#                7035425: [2, array([438, 469], dtype=int64)],
#                46782188: [2, array([425, 600], dtype=int64)],
#                1512303: [5,
#                 array([  49, 2018, 2024, 2032, 2108], dtype=int64)],
#                593630: [12,
#                 array([ 336,  439,  566,  698,  935, 1106, 1319, 1632, 1664, 1762, 1785,
#                        1852], dtype=int64)],
#                42663952: [1, array([170], dtype=int64)],
#                6131861: [2, array([83, 90], dtype=int64)],
#                584448: [6, array([250, 270, 280, 334, 336, 367], dtype=int64)],
#                215764: [7,
#                 array([ 309,  504,  572, 1214, 1301, 1386, 1388], dtype=int64)],
#                73423: [11,
#                 array([ 778,  860,  875,  887,  902,  948,  966,  986, 1013, 1184, 1318],
#                       dtype=int64)],
#                707912: [11,
#                 array([  15,  142,  694,  696,  819,  887, 1078, 1082, 1097, 1126, 1181],
#                       dtype=int64)],
#                1872229: [4, array([2626, 2705, 2787, 2842], dtype=int64)],
#                150035: [12,
#                 array([153, 155, 157, 234, 236, 238, 320, 331, 390, 396, 405, 461],
#                       dtype=int64)],
#                1065834: [2, array([ 563, 1575], dtype=int64)],
#                554919: [3, array([1306, 2071, 2100], dtype=int64)],
#                60262322: [6,
#                 array([630, 652, 688, 762, 806, 833], dtype=int64)],
#                13268827: [6,
#                 array([  87,  761, 1140, 1196, 1530, 1616], dtype=int64)],
#                197982: [1, array([618], dtype=int64)],
#                406512: [17,
#                 array([2855, 2921, 3465, 4336, 4454, 4846, 5228, 5309, 5365, 5416, 5636,
#                        5763, 5798, 5815, 5936, 7217, 7390], dtype=int64)],
#                4151646: [2, array([ 90, 139], dtype=int64)],
#                55901869: [2, array([450, 527], dtype=int64)],
#                12211231: [4, array([ 21, 118, 283, 287], dtype=int64)]}),
#              ('10',
#               {'1512303': [2, [2088, 2521]],
#                67921406: [1, array([150], dtype=int64)],
#                1168659: [2, array([562, 596], dtype=int64)],
#                1290848: [2, array([ 620, 2062], dtype=int64)],
#                1512303: [2, array([2088, 2521], dtype=int64)],
#                649708: [1, array([53], dtype=int64)],
#                707912: [11,
#                 array([1276, 1287, 1310, 1323, 1336, 1362, 1376, 1388, 1399, 1411, 1423],
#                       dtype=int64)],
#                1872229: [2, array([ 574, 2702], dtype=int64)],
#                1065834: [1, array([1704], dtype=int64)],
#                60262322: [2, array([285, 298], dtype=int64)],
#                13268827: [15,
#                 array([1042, 1144, 1156, 1171, 1184, 1200, 1213, 1219, 1223, 1235, 1249,
#                        1260, 1273, 1286, 1326], dtype=int64)],
#                406512: [8,
#                 array([2951, 2953, 4451, 4843, 4924, 6057, 6066, 7276], dtype=int64)]}),
#              ('100',
#               {'6335141': [1, [95]],
#                1290848: [1, array([398], dtype=int64)],
#                6335141: [1, array([95], dtype=int64)],
#                593630: [3, array([ 518,  567, 1540], dtype=int64)],
#                215764: [2, array([138, 317], dtype=int64)]}),
#              ('1000',
#               {'593630': [1, [823]],
#                1872229: [11,
#                 array([  74,   82,  123,  130, 1789, 2530, 2960, 2987, 3048, 3238, 3867],
#                       dtype=int64)]}),
#              ('101', {'73423': [1, [1115]]}),
#              ('1018', {'406512': [1, [4364]]}),
#              ('102', {'12211231': [1, [226]]}),
#              ('103', {'150035': [1, [510]]}),
#              ('10308', {'554919': [1, [512]]}),
#              ('1031',
#               {'6335141': [1, [395]],
#                6335141: [1, array([395], dtype=int64)]}),
#              ('104',
#               {'6335141': [1, [61]],
#                6335141: [1, array([61], dtype=int64)],
#                55901869: [1, array([578], dtype=int64)]}),
#              ('1049', {'406512': [1, [4474]]}),
#              ('1072', {'406512': [1, [4518]]}),
#              ('109',
#               {'554919': [1, [537]],
#                12211231: [2, array([225, 237], dtype=int64)]}),
#              ('11',
#               {'1512303': [4, [1904, 2284, 2393, 2514]],
#                1168659: [1, array([628], dtype=int64)],
#                6335141: [1, array([50], dtype=int64)],
#                1290848: [3, array([1272, 1277, 2206], dtype=int64)],
#                1512303: [4, array([1904, 2284, 2393, 2514], dtype=int64)],
#                1872229: [2, array([2652, 2758], dtype=int64)],
#                13268827: [7,
#                 array([  18, 1301, 1315, 1330, 1343, 1354, 1370], dtype=int64)],
#                406512: [4, array([2948, 5372, 6081, 7220], dtype=int64)],
#                55901869: [1, array([556], dtype=int64)]}),
#              ('111', {'12211231': [2, [218, 238]]}),
#              ('113', {'73423': [1, [872]]}),
#              ('1150', {'593630': [4, [1168, 1180, 1796, 1836]]}),
#              ('1151', {'593630': [4, [1253, 1266, 1797, 1837]]}),
#              ('1155', {'593630': [4, [1015, 1025, 1795, 1833]]}),
#              ('1156', {'593630': [4, [966, 975, 1793, 1831]]}),
#              ('1166',
#               {'6335141': [1, [557]],
#                6335141: [1, array([557], dtype=int64)]}),
#              ('119', {'554919': [1, [904]]}),
#              ('12',
#               {'1512303': [4, [2130, 2418, 2431, 2444]],
#                1168659: [1, array([229], dtype=int64)],
#                1290848: [1, array([393], dtype=int64)],
#                1512303: [4, array([2130, 2418, 2431, 2444], dtype=int64)],
#                707912: [2, array([ 237, 1348], dtype=int64)],
#                1872229: [1, array([2762], dtype=int64)],
#                60262322: [1, array([445], dtype=int64)],
#                13268827: [16,
#                 array([1385, 1400, 1414, 1426, 1439, 1455, 1466, 1478, 1493, 1506, 1521,
#                        1534, 1547, 1563, 1578, 1591], dtype=int64)],
#                406512: [7,
#                 array([4472, 4854, 5700, 5900, 6096, 6197, 7229], dtype=int64)],
#                55901869: [2, array([18, 49], dtype=int64)]}),
#              ('1200', {'593630': [4, [1414, 1424, 1799, 1840]]}),
#              ('1201', {'406512': [1, [4348]]}),
#              ('1207', {'593630': [2, [821, 999]]}),
#              ('1210256', {'73423': [1, [1257]]}),
#              ('122',
#               {'706315': [1, [87]], 706315: [1, array([87], dtype=int64)]}),
#              ('123', {'1872229': [1, [29]]}),
#              ('124',
#               {'1290848': [1, [550]],
#                1290848: [1, array([550], dtype=int64)]}),
#              ('1248', {'593630': [3, [1562, 1569, 1846]]}),
#              ('125', {'554919': [1, [1890]]}),
#              ('1250', {'593630': [1, [1913]]}),
#              ('12692092',
#               {'6335141': [1, [312]],
#                6335141: [1, array([312], dtype=int64)]}),
#              ('127',
#               {'406512': [1, [5344]],
#                12211231: [1, array([232], dtype=int64)]}),
#              ('1274', {'406512': [1, [4352]]}),
#              ('128', {'12211231': [1, [227]]}),
#              ('13',
#               {'1512303': [8,
#                 [1955, 2134, 2352, 2376, 2385, 2397, 2407, 2530]],
#                706315: [1, array([534], dtype=int64)],
#                1290848: [2, array([1626, 2417], dtype=int64)],
#                1512303: [8,
#                 array([1955, 2134, 2352, 2376, 2385, 2397, 2407, 2530], dtype=int64)],
#                707912: [1, array([56], dtype=int64)],
#                13268827: [1, array([1014], dtype=int64)],
#                406512: [7,
#                 array([1502, 2876, 5222, 5226, 5243, 5812, 7236], dtype=int64)],
#                55901869: [1, array([513], dtype=int64)]}),
#              ('1300', {'60262322': [2, [82, 165]]}),
#              ('132', {'593630': [1, [320]]}),
#              ('133', {'593630': [1, [1549]]}),
#              ('1331', {'593630': [1, [1318]]}),
#              ('1356', {'593630': [3, [1146, 1156, 1835]]}),
#              ('1366', {'593630': [4, [894, 906, 1792, 1830]]}),
#              ('1372',
#               {'67921406': [1, [74]],
#                67921406: [1, array([74], dtype=int64)]}),
#              ('1377', {'406512': [1, [4409]]}),
#              ('1389', {'406512': [1, [635]]}),
#              ('14',
#               {'1290848': [3, [747, 1604, 2402]],
#                1290848: [3, array([ 747, 1604, 2402], dtype=int64)],
#                1872229: [1, array([2766], dtype=int64)],
#                60262322: [2, array([126, 712], dtype=int64)],
#                13268827: [3, array([153, 253, 809], dtype=int64)],
#                406512: [5, array([2972, 4287, 4365, 6000, 7242], dtype=int64)],
#                55901869: [1, array([330], dtype=int64)]}),
#              ('140', {'593630': [1, [963]]}),
#              ('1400', {'593630': [1, [1151]]}),
#              ('143', {'12211231': [1, [233]]}),
#              ('144', {'73423': [1, [964]]}),
#              ('146', {'593630': [1, [1499]]}),
#              ('146576560', {'73423': [1, [1203]]}),
#              ('149', {'406512': [1, [5717]]}),
#              ('1491',
#               {'67921406': [1, [115]],
#                67921406: [1, array([115], dtype=int64)]}),
#              ('15',
#               {'1512303': [1, [2219]],
#                1290848: [1, array([1678], dtype=int64)],
#                1512303: [1, array([2219], dtype=int64)],
#                215764: [1, array([579], dtype=int64)],
#                707912: [1, array([216], dtype=int64)],
#                554919: [1, array([1341], dtype=int64)],
#                13268827: [3, array([ 791,  799, 1587], dtype=int64)],
#                197982: [1, array([701], dtype=int64)],
#                406512: [5, array([3562, 5608, 5930, 6172, 7247], dtype=int64)],
#                55901869: [3, array([434, 447, 496], dtype=int64)],
#                12211231: [1, array([253], dtype=int64)]}),
#              ('1500',
#               {'707912': [1, [92]], 554919: [1, array([837], dtype=int64)]}),
#              ('152', {'12211231': [1, [239]]}),
#              ('153145',
#               {'6335141': [1, [310]],
#                6335141: [1, array([310], dtype=int64)]}),
#              ('1567', {'593630': [3, [1005, 1013, 1832]]}),
#              ('1569', {'406512': [1, [2430]]}),
#              ('15797327',
#               {'6335141': [1, [486]],
#                6335141: [1, array([486], dtype=int64)]}),
#              ('158', {'12211231': [1, [230]]}),
#              ('1585', {'406512': [1, [774]]}),
#              ('1589', {'406512': [1, [759]]}),
#              ('16',
#               {'1512303': [3, [1338, 2106, 2440]],
#                1168659: [4, array([362, 480, 607, 653], dtype=int64)],
#                6335141: [2, array([306, 432], dtype=int64)],
#                7035425: [1, array([713], dtype=int64)],
#                46782188: [1, array([393], dtype=int64)],
#                1512303: [3, array([1338, 2106, 2440], dtype=int64)],
#                584448: [2, array([22, 49], dtype=int64)],
#                13268827: [1, array([987], dtype=int64)],
#                406512: [6,
#                 array([1311, 4724, 5472, 5996, 6177, 7254], dtype=int64)]}),
#              ('1600', {'593630': [2, [733, 773]]}),
#              ('166', {'55901869': [1, [402]]}),
#              ('168', {'593630': [2, [323, 327]]}),
#              ('169', {'593630': [1, [341]]}),
#              ('17',
#               {'1512303': [1, [2539]],
#                67921406: [1, array([101], dtype=int64)],
#                1290848: [2, array([556, 729], dtype=int64)],
#                1512303: [1, array([2539], dtype=int64)],
#                73423: [2, array([1173, 1183], dtype=int64)],
#                1872229: [2, array([ 443, 2623], dtype=int64)],
#                13268827: [2, array([ 973, 1297], dtype=int64)],
#                406512: [6,
#                 array([3576, 4399, 4649, 4834, 5062, 7260], dtype=int64)]}),
#              ('1700', {'593630': [3, [1426, 1433, 1800]]}),
#              ('1718', {'593630': [1, [1442]]}),
#              ('1729', {'584448': [2, [15, 48]]}),
#              ('1736', {'406512': [1, [886]]}),
#              ('1747', {'406512': [1, [617]]}),
#              ('176',
#               {'1290848': [1, [548]],
#                1290848: [1, array([548], dtype=int64)]}),
#              ('1765', {'584448': [1, [182]]}),
#              ('178',
#               {'1168659': [2, [231, 249]],
#                1168659: [2, array([231, 249], dtype=int64)]}),
#              ('1796', {'584448': [1, [24]]}),
#              ('18',
#               {'1512303': [2, [2043, 2471]],
#                1168659: [1, array([330], dtype=int64)],
#                6335141: [1, array([415], dtype=int64)],
#                1512303: [2, array([2043, 2471], dtype=int64)],
#                73423: [1, array([1254], dtype=int64)],
#                1872229: [1, array([2770], dtype=int64)],
#                1065834: [2, array([1664, 1675], dtype=int64)],
#                13268827: [2, array([1167, 1339], dtype=int64)],
#                406512: [5, array([2936, 5574, 6104, 6111, 7267], dtype=int64)],
#                55901869: [1, array([423], dtype=int64)]}),
#              ('1801', {'584448': [1, [108]]}),
#              ('1812',
#               {'1168659': [2, [9, 25]],
#                1168659: [2, array([ 9, 25], dtype=int64)]}),
#              ('1818',
#               {'6335141': [1, [376]],
#                6335141: [1, array([376], dtype=int64)]}),
#              ('1832',
#               {'46782188': [1, [572]],
#                46782188: [1, array([572], dtype=int64)]}),
#              ('18375122',
#               {'6335141': [1, [419]],
#                6335141: [1, array([419], dtype=int64)]}),
#              ('1839', {'406512': [1, [1818]]}),
#              ('1840',
#               {'1168659': [1, [70]], 1168659: [1, array([70], dtype=int64)]}),
#              ('1841',
#               {'1168659': [1, [34]], 1168659: [1, array([34], dtype=int64)]}),
#              ('1843',
#               {'1168659': [1, [114]],
#                1168659: [1, array([114], dtype=int64)]}),
#              ('185',
#               {'6335141': [1, [321]],
#                6335141: [1, array([321], dtype=int64)]}),
#              ('1853',
#               {'1168659': [1, [405]],
#                1168659: [1, array([405], dtype=int64)]}),
#              ('1854',
#               {'1168659': [1, [416]],
#                1168659: [1, array([416], dtype=int64)]}),
#              ('1856',
#               {'1168659': [2, [263, 408]],
#                1168659: [2, array([263, 408], dtype=int64)]}),
#              ('1858', {'406512': [1, [992]]}),
#              ('1862',
#               {'1168659': [1, [420]],
#                1168659: [1, array([420], dtype=int64)]}),
#              ('1868',
#               {'1168659': [1, [443]],
#                1168659: [1, array([443], dtype=int64)]}),
#              ('1870',
#               {'1168659': [1, [399]],
#                1168659: [1, array([399], dtype=int64)]}),
#              ('1877', {'707912': [1, [90]]}),
#              ('1886',
#               {'1168659': [1, [427]],
#                1168659: [1, array([427], dtype=int64)]}),
#              ('189', {'406512': [1, [5721]]}),
#              ('1894',
#               {'1168659': [1, [435]],
#                1168659: [1, array([435], dtype=int64)]}),
#              ('1899', {'1872229': [6, [28, 32, 137, 178, 643, 1294]]}),
#              ('19',
#               {'1512303': [8, [904, 2161, 2170, 2182, 2249, 2263, 2534, 2543]],
#                7035425: [1, array([615], dtype=int64)],
#                1512303: [8,
#                 array([ 904, 2161, 2170, 2182, 2249, 2263, 2534, 2543], dtype=int64)],
#                73423: [1, array([837], dtype=int64)],
#                406512: [7,
#                 array([ 447, 2496, 4612, 5460, 5476, 6237, 7273], dtype=int64)],
#                55901869: [1, array([613], dtype=int64)]}),
#              ('1900',
#               {'67921406': [1, [34]],
#                1168659: [1, array([15], dtype=int64)],
#                67921406: [1, array([34], dtype=int64)],
#                1872229: [2, array([ 648, 1299], dtype=int64)]}),
#              ('1901', {'1872229': [3, [141, 653, 1304]]}),
#              ('1902',
#               {'46782188': [1, [540]],
#                46782188: [1, array([540], dtype=int64)],
#                1872229: [2, array([ 658, 1309], dtype=int64)]}),
#              ('1903', {'1872229': [2, [663, 1314]]}),
#              ('1904',
#               {'1872229': [2, [668, 1319]],
#                554919: [1, array([1009], dtype=int64)]}),
#              ('1905', {'1872229': [2, [673, 1324]]}),
#              ('1906', {'1872229': [2, [678, 1329]]}),
#              ('1907',
#               {'1872229': [2, [683, 1334]],
#                406512: [1, array([3657], dtype=int64)]}),
#              ('1908', {'1872229': [2, [689, 1339]]}),
#              ('1909',
#               {'1872229': [2, [694, 1344]],
#                406512: [1, array([4289], dtype=int64)]}),
#              ('1910', {'1872229': [2, [699, 1349]]}),
#              ('1911',
#               {'1872229': [2, [704, 1354]],
#                554919: [2, array([1617, 1711], dtype=int64)],
#                406512: [1, array([1018], dtype=int64)]}),
#              ('1912',
#               {'1872229': [2, [709, 1359]],
#                406512: [2, array([1013, 1044], dtype=int64)]}),
#              ('1913',
#               {'1872229': [2, [713, 1365]],
#                554919: [1, array([1663], dtype=int64)]}),
#              ('1914', {'1872229': [2, [718, 1370]]}),
#              ('1915', {'1872229': [2, [723, 1375]]}),
#              ('1916', {'1872229': [2, [728, 1380]]}),
#              ('1917', {'1872229': [2, [734, 1385]]}),
#              ('1918',
#               {'46782188': [1, [573]],
#                46782188: [1, array([573], dtype=int64)],
#                1872229: [2, array([ 739, 1390], dtype=int64)]}),
#              ('1919',
#               {'1872229': [2, [745, 1396]],
#                554919: [1, array([1618], dtype=int64)],
#                406512: [1, array([4334], dtype=int64)]}),
#              ('1920',
#               {'46782188': [1, [659]],
#                46782188: [1, array([659], dtype=int64)],
#                1872229: [2, array([ 750, 1398], dtype=int64)],
#                554919: [1, array([1177], dtype=int64)]}),
#              ('1921', {'1872229': [3, [755, 1404, 2715]]}),
#              ('1922', {'1872229': [2, [758, 1407]]}),
#              ('19220', {'554919': [1, [516]]}),
#              ('1923', {'1872229': [2, [763, 1413]]}),
#              ('1924', {'1872229': [2, [768, 1420]]}),
#              ('1925',
#               {'1872229': [2, [773, 1426]],
#                55901869: [2, array([14, 48], dtype=int64)]}),
#              ('1926', {'1872229': [2, [778, 1432]]}),
#              ('1927',
#               {'1872229': [2, [783, 1439]],
#                554919: [1, array([1638], dtype=int64)],
#                60262322: [2, array([39, 74], dtype=int64)]}),
#              ('1928',
#               {'46782188': [1, [574]],
#                46782188: [1, array([574], dtype=int64)],
#                1872229: [2, array([ 788, 1446], dtype=int64)]}),
#              ('1929', {'1872229': [2, [793, 1452]]}),
#              ('1930',
#               {'1872229': [2, [798, 1458]],
#                406512: [1, array([5117], dtype=int64)]}),
#              ('1931', {'1872229': [2, [803, 1464]]}),
#              ('1932', {'1872229': [2, [808, 1470]]}),
#              ('1933', {'1872229': [2, [813, 1477]]}),
#              ('1934', {'1872229': [2, [818, 1482]]}),
#              ('1935',
#               {'1872229': [2, [823, 1488]],
#                60262322: [1, array([204], dtype=int64)],
#                406512: [2, array([1155, 4151], dtype=int64)]}),
#              ('1936',
#               {'1872229': [2, [829, 1494]],
#                150035: [1, array([38], dtype=int64)],
#                406512: [2, array([4695, 4963], dtype=int64)]}),
#              ('1937',
#               {'1872229': [2, [834, 1499]],
#                406512: [1, array([4778], dtype=int64)]}),
#              ('1938', {'1872229': [2, [839, 1504]]}),
#              ('1939', {'1872229': [2, [844, 1509]]}),
#              ('1940',
#               {'1872229': [2, [849, 1514]],
#                406512: [1, array([4742], dtype=int64)]}),
#              ('1941',
#               {'1872229': [2, [854, 1519]],
#                406512: [1, array([1251], dtype=int64)]}),
#              ('1942', {'1872229': [2, [859, 1524]]}),
#              ('1943',
#               {'1872229': [2, [864, 1529]],
#                55901869: [1, array([129], dtype=int64)]}),
#              ('1944', {'1872229': [2, [869, 1534]]}),
#              ('1945', {'1872229': [2, [874, 1539]]}),
#              ('1946', {'1872229': [2, [879, 1544]]}),
#              ('1947',
#               {'1872229': [2, [884, 1549]],
#                406512: [1, array([4490], dtype=int64)]}),
#              ('1948',
#               {'1872229': [2, [889, 1555]],
#                60262322: [1, array([233], dtype=int64)],
#                406512: [1, array([1257], dtype=int64)]}),
#              ('1949', {'1872229': [2, [894, 1562]]}),
#              ('1950',
#               {'1872229': [2, [899, 1568]],
#                406512: [1, array([4726], dtype=int64)],
#                55901869: [2, array([149, 400], dtype=int64)]}),
#              ('1951',
#               {'1872229': [2, [904, 1574]],
#                406512: [2, array([4220, 4836], dtype=int64)]}),
#              ('1952', {'1872229': [2, [909, 1579]]}),
#              ('1953', {'1872229': [2, [915, 1584]]}),
#              ('1954',
#               {'1872229': [2, [920, 1590]],
#                55901869: [1, array([194], dtype=int64)]}),
#              ('1955', {'1872229': [2, [925, 1595]]}),
#              ('1956',
#               {'1872229': [2, [930, 1600]],
#                554919: [2, array([716, 724], dtype=int64)],
#                406512: [2, array([1116, 1276], dtype=int64)]}),
#              ('1957',
#               {'1872229': [2, [935, 1606]],
#                55901869: [1, array([209], dtype=int64)]}),
#              ('1958',
#               {'1872229': [2, [940, 1611]],
#                406512: [1, array([4658], dtype=int64)]}),
#              ('1959',
#               {'30524820': [2, [57, 141]],
#                1872229: [2, array([ 945, 1616], dtype=int64)],
#                406512: [3, array([4173, 4257, 4807], dtype=int64)],
#                55901869: [1, array([213], dtype=int64)]}),
#              ('1960', {'1872229': [2, [950, 1621]]}),
#              ('1961',
#               {'73423': [1, [447]],
#                1872229: [2, array([ 955, 1626], dtype=int64)],
#                406512: [1, array([4313], dtype=int64)]}),
#              ('1962', {'1872229': [2, [960, 1632]]}),
#              ('1963',
#               {'1512303': [1, [672]],
#                1512303: [1, array([672], dtype=int64)],
#                73423: [5, array([  6,  58,  59,  71, 763], dtype=int64)],
#                1872229: [2, array([ 965, 1637], dtype=int64)]}),
#              ('1964',
#               {'73423': [1, [122]],
#                1872229: [2, array([ 970, 1642], dtype=int64)]}),
#              ('1965',
#               {'46782188': [1, [589]],
#                46782188: [1, array([589], dtype=int64)],
#                1872229: [2, array([ 975, 1647], dtype=int64)],
#                406512: [2, array([1332, 4376], dtype=int64)]}),
#              ('1966', {'1872229': [2, [980, 1652]]}),
#              ('1967',
#               {'1872229': [2, [985, 1657]],
#                406512: [1, array([4814], dtype=int64)],
#                55901869: [2, array([  7, 271], dtype=int64)]}),
#              ('1968',
#               {'1872229': [5, [992, 1662, 1804, 2305, 2897]],
#                406512: [2, array([4771, 4826], dtype=int64)],
#                55901869: [1, array([258], dtype=int64)]}),
#              ('1969',
#               {'1872229': [6, [145, 997, 1667, 1813, 2314, 2898]],
#                55901869: [2, array([272, 300], dtype=int64)]}),
#              ('1970',
#               {'1872229': [6, [1002, 1674, 1822, 2323, 2645, 2899]],
#                406512: [2, array([3676, 4926], dtype=int64)]}),
#              ('1971',
#               {'1872229': [5, [1007, 1680, 1831, 2332, 2900]],
#                554919: [1, array([405], dtype=int64)],
#                406512: [2, array([4639, 5004], dtype=int64)]}),
#              ('1972',
#               {'707912': [1, [427]],
#                1872229: [5,
#                 array([1012, 1685, 1841, 2341, 2901], dtype=int64)],
#                406512: [1, array([5064], dtype=int64)]}),
#              ('1973',
#               {'707912': [1, [1169]],
#                1872229: [5,
#                 array([1017, 1690, 1850, 2350, 2902], dtype=int64)],
#                406512: [1, array([4651], dtype=int64)]}),
#              ('1974',
#               {'593630': [1, [988]],
#                215764: [1, array([45], dtype=int64)],
#                1872229: [3, array([1022, 1859, 2903], dtype=int64)],
#                406512: [1, array([1243], dtype=int64)]}),
#              ('1975',
#               {'1872229': [3, [1027, 1868, 2904]],
#                60262322: [1, array([251], dtype=int64)],
#                406512: [3, array([1324, 4601, 4625], dtype=int64)]}),
#              ('1976',
#               {'1872229': [3, [1032, 1877, 2905]],
#                406512: [1, array([4758], dtype=int64)]}),
#              ('1977',
#               {'11684110': [3, [0, 7, 13]],
#                11684110: [3, array([ 0,  7, 13], dtype=int64)],
#                1872229: [3, array([1037, 1887, 2906], dtype=int64)],
#                406512: [2, array([1359, 4704], dtype=int64)]}),
#              ('1978', {'1872229': [4, [193, 1042, 1896, 2907]]}),
#              ('1979',
#               {'6335141': [1, [126]],
#                6335141: [1, array([126], dtype=int64)],
#                1872229: [7,
#                 array([ 323, 1047, 1265, 1269, 1283, 1905, 2908], dtype=int64)],
#                406512: [1, array([2034], dtype=int64)]}),
#              ('1980',
#               {'1872229': [3, [1053, 1914, 2909]],
#                554919: [1, array([1578], dtype=int64)],
#                406512: [1, array([4911], dtype=int64)]}),
#              ('1981', {'1872229': [5, [309, 469, 1058, 1923, 2910]]}),
#              ('1982',
#               {'1512303': [2, [103, 150]],
#                1512303: [2, array([103, 150], dtype=int64)],
#                1872229: [3, array([1063, 1932, 2911], dtype=int64)],
#                406512: [1, array([4897], dtype=int64)],
#                12211231: [1, array([17], dtype=int64)]}),
#              ('1983',
#               {'1512303': [2, [153, 1161]],
#                1512303: [2, array([ 153, 1161], dtype=int64)],
#                1872229: [3, array([1068, 1941, 2912], dtype=int64)],
#                55901869: [1, array([306], dtype=int64)]}),
#              ('1984',
#               {'1512303': [1, [157]],
#                1512303: [1, array([157], dtype=int64)],
#                6131861: [1, array([85], dtype=int64)],
#                707912: [1, array([514], dtype=int64)],
#                1872229: [3, array([1073, 1950, 2913], dtype=int64)],
#                55901869: [1, array([307], dtype=int64)]}),
#              ('1985',
#               {'1512303': [1, [158]],
#                1512303: [1, array([158], dtype=int64)],
#                1872229: [4, array([1078, 1959, 2640, 2914], dtype=int64)]}),
#              ('1986',
#               {'1512303': [1, [165]],
#                1512303: [1, array([165], dtype=int64)],
#                1872229: [3, array([1083, 1968, 2915], dtype=int64)],
#                406512: [1, array([1644], dtype=int64)]}),
#              ('1987',
#               {'1512303': [1, [169]],
#                1512303: [1, array([169], dtype=int64)],
#                1872229: [3, array([1088, 1977, 2916], dtype=int64)]}),
#              ('1988',
#               {'1512303': [1, [172]],
#                1512303: [1, array([172], dtype=int64)],
#                1872229: [6,
#                 array([ 372, 1093, 1696, 1986, 2360, 2917], dtype=int64)]}),
#              ('1989',
#               {'1512303': [1, [176]],
#                1512303: [1, array([176], dtype=int64)],
#                593630: [1, array([337], dtype=int64)],
#                1872229: [4, array([ 310, 1098, 1995, 2918], dtype=int64)]}),
#              ('1989762', {'150035': [1, [498]]}),
#              ('1990',
#               {'1512303': [1, [179]],
#                1512303: [1, array([179], dtype=int64)],
#                1872229: [6,
#                 array([1103, 2004, 2919, 3125, 3127, 3129], dtype=int64)],
#                13268827: [2, array([20, 95], dtype=int64)]}),
#              ('1991',
#               {'1512303': [1, [184]],
#                1512303: [1, array([184], dtype=int64)],
#                593630: [1, array([352], dtype=int64)],
#                1872229: [3, array([1108, 2013, 2920], dtype=int64)],
#                554919: [2, array([1052, 1070], dtype=int64)],
#                406512: [1, array([1645], dtype=int64)]}),
#              ('1992',
#               {'1512303': [1, [187]],
#                1512303: [1, array([187], dtype=int64)],
#                1872229: [3, array([1113, 2022, 2921], dtype=int64)]}),
#              ('1993',
#               {'1512303': [1, [188]],
#                1512303: [1, array([188], dtype=int64)],
#                593630: [1, array([361], dtype=int64)],
#                1872229: [4, array([1118, 2031, 2922, 3141], dtype=int64)],
#                1065834: [1, array([49], dtype=int64)],
#                406512: [1, array([1417], dtype=int64)],
#                55901869: [1, array([350], dtype=int64)]}),
#              ('1994',
#               {'1512303': [1, [192]],
#                1512303: [1, array([192], dtype=int64)],
#                593630: [3, array([369, 392, 399], dtype=int64)],
#                215764: [2, array([ 290, 1109], dtype=int64)],
#                1872229: [3, array([1123, 2040, 2923], dtype=int64)],
#                406512: [3, array([1384, 3714, 5458], dtype=int64)],
#                55901869: [1, array([409], dtype=int64)]}),
#              ('1995',
#               {'1512303': [2, [193, 2276]],
#                1512303: [2, array([ 193, 2276], dtype=int64)],
#                593630: [3, array([ 431, 1495, 1508], dtype=int64)],
#                215764: [2, array([1083, 1130], dtype=int64)],
#                1872229: [5,
#                 array([ 472, 1128, 2049, 2924, 3157], dtype=int64)],
#                406512: [1, array([3740], dtype=int64)]}),
#              ('1996',
#               {'1512303': [1, [197]],
#                706315: [5, array([   3,  171,  506,  890, 1106], dtype=int64)],
#                1290848: [1, array([140], dtype=int64)],
#                1512303: [1, array([197], dtype=int64)],
#                215764: [1, array([892], dtype=int64)],
#                1872229: [4, array([1133, 2059, 2925, 3163], dtype=int64)],
#                60262322: [1, array([86], dtype=int64)],
#                406512: [1, array([1646], dtype=int64)]}),
#              ('1997',
#               {'1512303': [3, [198, 806, 1723]],
#                706315: [4, array([508, 512, 892, 901], dtype=int64)],
#                1512303: [3, array([ 198,  806, 1723], dtype=int64)],
#                593630: [2, array([ 440, 1517], dtype=int64)],
#                215764: [2, array([383, 894], dtype=int64)],
#                1872229: [4, array([ 478, 1138, 2068, 2926], dtype=int64)]}),
#              ('1998',
#               {'1512303': [3, [201, 1306, 1343]],
#                706315: [6,
#                 array([ 514,  518,  903,  908, 1126, 1155], dtype=int64)],
#                1290848: [6,
#                 array([ 46, 128, 574, 908, 923, 960], dtype=int64)],
#                1512303: [3, array([ 201, 1306, 1343], dtype=int64)],
#                593630: [3, array([ 466,  485, 1526], dtype=int64)],
#                584448: [1, array([161], dtype=int64)],
#                215764: [1, array([1058], dtype=int64)],
#                1872229: [5,
#                 array([1143, 2077, 2927, 3173, 3175], dtype=int64)],
#                406512: [1, array([1445], dtype=int64)]}),
#              ('1999',
#               {'1512303': [3, [205, 422, 1385]],
#                706315: [6,
#                 array([ 520,  524,  910,  917, 1147, 1171], dtype=int64)],
#                1290848: [7,
#                 array([ 579,  761,  816,  874,  909,  918, 1928], dtype=int64)],
#                1512303: [3, array([ 205,  422, 1385], dtype=int64)],
#                593630: [4, array([ 499,  512,  522, 1534], dtype=int64)],
#                1872229: [4, array([1148, 2087, 2928, 3177], dtype=int64)],
#                406512: [1, array([3158], dtype=int64)]}),
#              ('2',
#               {'1512303': [14,
#                 [83,
#                  477,
#                  567,
#                  782,
#                  795,
#                  1394,
#                  1423,
#                  2019,
#                  2025,
#                  2033,
#                  2109,
#                  2391,
#                  2464,
#                  2477]],
#                67921406: [1, array([260], dtype=int64)],
#                1168659: [3, array([522, 566, 617], dtype=int64)],
#                706315: [5, array([ 509,  899, 1355, 1377, 1396], dtype=int64)],
#                6335141: [1, array([269], dtype=int64)],
#                1290848: [5,
#                 array([1995, 2016, 2023, 2117, 3107], dtype=int64)],
#                7035425: [2, array([454, 485], dtype=int64)],
#                46782188: [1, array([426], dtype=int64)],
#                1512303: [14,
#                 array([  83,  477,  567,  782,  795, 1394, 1423, 2019, 2025, 2033, 2109,
#                        2391, 2464, 2477], dtype=int64)],
#                593630: [13,
#                 array([ 344,  378,  484,  722,  726,  755,  886, 1555, 1633, 1665, 1764,
#                        1824, 1854], dtype=int64)],
#                42663952: [1, array([171], dtype=int64)],
#                584448: [5, array([ 13,  46, 251, 271, 281], dtype=int64)],
#                215764: [8,
#                 array([ 322,  414,  918,  933, 1215, 1302, 1369, 1403], dtype=int64)],
#                73423: [9,
#                 array([ 779,  861,  876,  888,  903,  949,  967,  987, 1014], dtype=int64)],
#                30524820: [2, array([100, 104], dtype=int64)],
#                707912: [10,
#                 array([  44,   48,  143,  691,  907, 1075, 1083, 1098, 1127, 1182],
#                       dtype=int64)],
#                1872229: [4, array([ 489, 2653, 2788, 2843], dtype=int64)],
#                150035: [12,
#                 array([154, 156, 158, 235, 237, 239, 324, 335, 391, 399, 408, 462],
#                       dtype=int64)],
#                1065834: [2, array([1535, 1576], dtype=int64)],
#                554919: [3, array([1304, 2072, 2101], dtype=int64)],
#                60262322: [6,
#                 array([631, 653, 689, 763, 807, 834], dtype=int64)],
#                13268827: [4, array([ 713,  880, 1231, 1282], dtype=int64)],
#                406512: [21,
#                 array([  70,  111, 1782, 1955, 2763, 2879, 2885, 2933, 2944, 2961, 4693,
#                        4769, 5229, 5366, 5417, 5799, 5816, 5851, 5937, 6132, 7225],
#                       dtype=int64)],
#                55901869: [2, array([451, 528], dtype=int64)],
#                12211231: [3, array([176, 268, 272], dtype=int64)]}),
#              ('20',
#               {'1512303': [2, [2178, 2316]],
#                67921406: [1, array([131], dtype=int64)],
#                6335141: [1, array([482], dtype=int64)],
#                1512303: [2, array([2178, 2316], dtype=int64)],
#                593630: [1, array([1033], dtype=int64)],
#                73423: [1, array([815], dtype=int64)],
#                707912: [1, array([1114], dtype=int64)],
#                406512: [12,
#                 array([  80, 1389, 1402, 1651, 1734, 1950, 2651, 2893, 5456, 5490, 6087,
#                        7280], dtype=int64)]}),
#              ('200',
#               {'593630': [3, [1315, 1559, 1907]],
#                215764: [1, array([817], dtype=int64)],
#                406512: [1, array([1269], dtype=int64)]}),
#              ('2000',
#               {'1512303': [2, [207, 2395]],
#                706315: [5, array([ 526,  530,  919,  926, 1192], dtype=int64)],
#                1290848: [5,
#                 array([  39,  682,  715,  902, 2085], dtype=int64)],
#                46782188: [1, array([362], dtype=int64)],
#                1512303: [2, array([ 207, 2395], dtype=int64)],
#                593630: [4, array([537, 559, 580, 828], dtype=int64)],
#                215764: [1, array([935], dtype=int64)],
#                1872229: [3, array([1153, 2096, 2929], dtype=int64)],
#                554919: [1, array([1702], dtype=int64)],
#                60262322: [2, array([ 81, 164], dtype=int64)],
#                12211231: [1, array([99], dtype=int64)]}),
#              ('2001',
#               {'1512303': [2, [212, 2374]],
#                706315: [6,
#                 array([ 532,  536,  928,  935, 1033, 1229], dtype=int64)],
#                1512303: [2, array([ 212, 2374], dtype=int64)],
#                593630: [3, array([ 592,  602, 1543], dtype=int64)],
#                215764: [3, array([ 527,  898, 1095], dtype=int64)],
#                1872229: [4, array([1158, 2105, 2930, 3183], dtype=int64)],
#                4151646: [1, array([78], dtype=int64)]}),
#              ('2002',
#               {'1512303': [2, [219, 1953]],
#                706315: [5, array([ 173,  538,  937, 1282, 1410], dtype=int64)],
#                1290848: [2, array([1141, 1327], dtype=int64)],
#                1512303: [2, array([ 219, 1953], dtype=int64)],
#                593630: [3, array([ 620,  631, 1552], dtype=int64)],
#                215764: [2, array([905, 948], dtype=int64)],
#                30524820: [1, array([200], dtype=int64)],
#                1872229: [3, array([1163, 2114, 2931], dtype=int64)]}),
#              ('2003',
#               {'1512303': [1, [223]],
#                706315: [1, array([1326], dtype=int64)],
#                1512303: [1, array([223], dtype=int64)],
#                593630: [3, array([640, 655, 668], dtype=int64)],
#                215764: [1, array([961], dtype=int64)],
#                1872229: [3, array([1168, 2123, 2932], dtype=int64)],
#                554919: [1, array([1077], dtype=int64)],
#                197982: [1, array([620], dtype=int64)],
#                406512: [1, array([1446], dtype=int64)],
#                12211231: [1, array([107], dtype=int64)]}),
#              ('2004',
#               {'1512303': [1, [229]],
#                1290848: [1, array([2078], dtype=int64)],
#                1512303: [1, array([229], dtype=int64)],
#                593630: [2, array([679, 708], dtype=int64)],
#                215764: [2, array([1066, 1100], dtype=int64)],
#                1872229: [6,
#                 array([ 374, 1173, 1702, 2132, 2370, 2933], dtype=int64)],
#                12211231: [1, array([112], dtype=int64)]}),
#              ('2005',
#               {'1512303': [3, [239, 666, 1747]],
#                1290848: [1, array([2614], dtype=int64)],
#                1512303: [3, array([ 239,  666, 1747], dtype=int64)],
#                215764: [1, array([967], dtype=int64)],
#                1872229: [5,
#                 array([1178, 1707, 2141, 2379, 2934], dtype=int64)],
#                13268827: [3, array([ 25, 801, 961], dtype=int64)],
#                12211231: [1, array([116], dtype=int64)]}),
#              ('2006',
#               {'1512303': [7, [244, 709, 1943, 1957, 2045, 2055, 2280]],
#                1512303: [7,
#                 array([ 244,  709, 1943, 1957, 2045, 2055, 2280], dtype=int64)],
#                593630: [5, array([743, 767, 779, 788, 807], dtype=int64)],
#                215764: [1, array([909], dtype=int64)],
#                1872229: [5,
#                 array([1183, 1712, 2150, 2389, 2935], dtype=int64)],
#                554919: [1, array([1345], dtype=int64)],
#                13268827: [4, array([811, 821, 831, 975], dtype=int64)],
#                406512: [2, array([1647, 5245], dtype=int64)],
#                12211231: [2, array([134, 201], dtype=int64)]}),
#              ('2007',
#               {'1512303': [3, [245, 2304, 2383]],
#                1290848: [1, array([2333], dtype=int64)],
#                1512303: [3, array([ 245, 2304, 2383], dtype=int64)],
#                593630: [2, array([855, 883], dtype=int64)],
#                584448: [1, array([295], dtype=int64)],
#                215764: [3, array([609, 842, 974], dtype=int64)],
#                707912: [1, array([1080], dtype=int64)],
#                1872229: [5,
#                 array([1189, 1717, 2159, 2399, 2936], dtype=int64)],
#                554919: [2, array([ 889, 1956], dtype=int64)],
#                13268827: [10,
#                 array([ 733,  841,  851,  861,  872,  989, 1003, 1016, 1030, 1091],
#                       dtype=int64)],
#                406512: [4, array([3667, 5720, 5830, 5898], dtype=int64)],
#                12211231: [2, array([153, 202], dtype=int64)]}),
#              ('2008',
#               {'1512303': [5, [246, 769, 790, 1642, 2314]],
#                706315: [2, array([1413, 1421], dtype=int64)],
#                1290848: [1, array([2343], dtype=int64)],
#                7035425: [1, array([715], dtype=int64)],
#                1512303: [5,
#                 array([ 246,  769,  790, 1642, 2314], dtype=int64)],
#                593630: [2, array([896, 914], dtype=int64)],
#                215764: [1, array([733], dtype=int64)],
#                1872229: [6,
#                 array([1194, 1722, 2168, 2408, 2937, 3197], dtype=int64)],
#                13268827: [6,
#                 array([ 746,  882,  892,  902, 1092, 1109], dtype=int64)],
#                406512: [1, array([5509], dtype=int64)],
#                12211231: [2, array([159, 203], dtype=int64)]}),
#              ('2009',
#               {'1512303': [1, [249]],
#                1290848: [1, array([1414], dtype=int64)],
#                46782188: [2, array([38, 55], dtype=int64)],
#                1512303: [1, array([249], dtype=int64)],
#                593630: [2, array([937, 968], dtype=int64)],
#                1872229: [6,
#                 array([1199, 1730, 2177, 2420, 2938, 3059], dtype=int64)],
#                554919: [3, array([  34, 1959, 2056], dtype=int64)],
#                13268827: [4, array([ 912, 1044, 1093, 1110], dtype=int64)],
#                406512: [5, array([ 228, 3159, 3744, 5462, 5478], dtype=int64)],
#                12211231: [2, array([171, 204], dtype=int64)]}),
#              ('2010',
#               {'1512303': [6, [250, 799, 828, 2086, 2090, 2416]],
#                1168659: [1, array([528], dtype=int64)],
#                1290848: [1, array([2322], dtype=int64)],
#                1512303: [6,
#                 array([ 250,  799,  828, 2086, 2090, 2416], dtype=int64)],
#                593630: [4, array([ 982,  993, 1007, 1563], dtype=int64)],
#                215764: [1, array([1322], dtype=int64)],
#                73423: [1, array([1310], dtype=int64)],
#                1872229: [9,
#                 array([ 475, 1204, 1735, 2186, 2431, 2796, 2939, 3060, 3225], dtype=int64)],
#                1065834: [2, array([ 388, 1137], dtype=int64)],
#                554919: [1, array([2099], dtype=int64)],
#                60262322: [2, array([  9, 325], dtype=int64)],
#                13268827: [4, array([ 922,  932, 1094, 1111], dtype=int64)],
#                406512: [6,
#                 array([2757, 3700, 4596, 5241, 5496, 6098], dtype=int64)],
#                55901869: [1, array([20], dtype=int64)],
#                12211231: [2, array([174, 205], dtype=int64)]}),
#              ('2011',
#               {'1512303': [4, [257, 900, 2290, 2294]],
#                1290848: [3, array([2297, 2396, 2399], dtype=int64)],
#                1512303: [4, array([ 257,  900, 2290, 2294], dtype=int64)],
#                593630: [10,
#                 array([1046, 1071, 1082, 1090, 1108, 1118, 1129, 1238, 1794, 1834],
#                       dtype=int64)],
#                215764: [1, array([1332], dtype=int64)],
#                1872229: [8,
#                 array([ 407, 1209, 1740, 2195, 2440, 2665, 2940, 3061], dtype=int64)],
#                1065834: [2, array([1732, 1735], dtype=int64)],
#                554919: [3, array([1002, 1919, 1924], dtype=int64)],
#                60262322: [1, array([518], dtype=int64)],
#                13268827: [7,
#                 array([  54,   57,  193,  264,  942, 1095, 1112], dtype=int64)],
#                406512: [8,
#                 array([1648, 2841, 3688, 3727, 5943, 5947, 6094, 6113], dtype=int64)],
#                12211231: [2, array([183, 206], dtype=int64)]}),
#              ('2012',
#               {'1512303': [7, [108, 258, 2342, 2350, 2361, 2429, 2442]],
#                1168659: [1, array([564], dtype=int64)],
#                1290848: [1, array([1181], dtype=int64)],
#                46782188: [1, array([188], dtype=int64)],
#                1512303: [7,
#                 array([ 108,  258, 2342, 2350, 2361, 2429, 2442], dtype=int64)],
#                593630: [2, array([1148, 1158], dtype=int64)],
#                215764: [2, array([1325, 1335], dtype=int64)],
#                1872229: [6,
#                 array([1215, 1745, 2204, 2449, 2941, 3062], dtype=int64)],
#                13268827: [4, array([  58,   60, 1096, 1113], dtype=int64)],
#                197982: [1, array([32], dtype=int64)],
#                406512: [5, array([4000, 5403, 5474, 6117, 6183], dtype=int64)],
#                12211231: [1, array([207], dtype=int64)]}),
#              ('2013',
#               {'1512303': [8, [261, 1771, 2159, 2168, 2180, 2338, 2486, 2490]],
#                67921406: [2, array([ 31, 224], dtype=int64)],
#                6335141: [1, array([284], dtype=int64)],
#                1290848: [8,
#                 array([1981, 2447, 2450, 2460, 2463, 2469, 2472, 2484], dtype=int64)],
#                46782188: [1, array([179], dtype=int64)],
#                1512303: [8,
#                 array([ 261, 1771, 2159, 2168, 2180, 2338, 2486, 2490], dtype=int64)],
# ...
#              ('anniversari',
#               {'1512303': [3, [517, 915, 1791]],
#                1512303: [3, array([ 517,  915, 1791], dtype=int64)],
#                42663952: [1, array([133], dtype=int64)],
#                1872229: [1, array([2873], dtype=int64)],
#                1065834: [1, array([1833], dtype=int64)],
#                554919: [1, array([827], dtype=int64)],
#                406512: [1, array([229], dtype=int64)]}),
#              ('annoi',
#               {'706315': [1, [340]], 706315: [1, array([340], dtype=int64)]}),
#              ('announc',
#               {'1512303': [10,
#                 [708, 907, 1114, 1167, 1189, 1198, 1456, 1568, 2114, 2243]],
#                1290848: [11,
#                 array([ 799, 1195, 1231, 1435, 1469, 1482, 1488, 1561, 1742, 1768, 1780],
#                       dtype=int64)],
#                1512303: [10,
#                 array([ 708,  907, 1114, 1167, 1189, 1198, 1456, 1568, 2114, 2243],
#                       dtype=int64)],
#                73423: [1, array([303], dtype=int64)],
#                1872229: [3, array([481, 521, 547], dtype=int64)],
#                1065834: [1, array([1687], dtype=int64)],
#                60262322: [2, array([334, 475], dtype=int64)]}),
#              ('annual',
#               {'1290848': [2, [906, 2308]],
#                1290848: [2, array([ 906, 2308], dtype=int64)],
#                73423: [2, array([ 163, 1124], dtype=int64)],
#                30524820: [1, array([110], dtype=int64)],
#                1872229: [1, array([94], dtype=int64)],
#                1065834: [1, array([221], dtype=int64)],
#                60262322: [1, array([293], dtype=int64)],
#                406512: [2, array([1538, 2061], dtype=int64)]}),
#              ('annurevan', {'73423': [1, [1129]]}),
#              ('ano',
#               {'7035425': [3, [510, 525, 539]],
#                7035425: [3, array([510, 525, 539], dtype=int64)]}),
#              ('anoka', {'60262322': [1, [873]]}),
#              ('anonym', {'73423': [3, [828, 1175, 1186]]}),
#              ('anoth',
#               {'1512303': [4, [1164, 1371, 1664, 1792]],
#                706315: [1, array([746], dtype=int64)],
#                1290848: [3, array([ 365, 1365, 1905], dtype=int64)],
#                1512303: [4, array([1164, 1371, 1664, 1792], dtype=int64)],
#                73423: [1, array([280], dtype=int64)],
#                1872229: [1, array([532], dtype=int64)],
#                1065834: [2, array([ 314, 1258], dtype=int64)]}),
#              ('anousheh', {'406512': [2, [4106, 4851]]}),
#              ('anoushirvan', {'406512': [1, [4618]]}),
#              ('ansari', {'406512': [3, [4107, 4120, 4852]]}),
#              ('ansu',
#               {'7035425': [1, [1890]],
#                7035425: [1, array([1890], dtype=int64)]}),
#              ('answer',
#               {'706315': [1, [790]], 706315: [1, array([790], dtype=int64)]}),
#              ('antagonist', {'1065834': [1, [1156]]}),
#              ('anthologi',
#               {'1512303': [1, [2282]],
#                1512303: [1, array([2282], dtype=int64)]}),
#              ('anthoni',
#               {'46782188': [3, [643, 757, 798]],
#                46782188: [3, array([643, 757, 798], dtype=int64)],
#                12211231: [1, array([368], dtype=int64)]}),
#              ('anthropolog',
#               {'46782188': [1, [1039]],
#                46782188: [1, array([1039], dtype=int64)],
#                73423: [9,
#                 array([ 568,  595,  892, 1112, 1126, 1199, 1235, 1265, 1286], dtype=int64)]}),
#              ('anthropologist',
#               {'73423': [6, [431, 434, 871, 1114, 1143, 1214]]}),
#              ('antiabort',
#               {'46782188': [1, [852]],
#                46782188: [1, array([852], dtype=int64)]}),
#              ('antialbin',
#               {'46782188': [1, [1178]],
#                46782188: [1, array([1178], dtype=int64)]}),
#              ('antiautism',
#               {'46782188': [1, [1179]],
#                46782188: [1, array([1179], dtype=int64)]}),
#              ('antibacteri',
#               {'6335141': [2, [176, 194]],
#                6335141: [2, array([176, 194], dtype=int64)]}),
#              ('antibiot',
#               {'6335141': [6, [25, 81, 104, 117, 190, 300]],
#                6335141: [6,
#                 array([ 25,  81, 104, 117, 190, 300], dtype=int64)]}),
#              ('anticultur',
#               {'46782188': [1, [1529]],
#                46782188: [1, array([1529], dtype=int64)]}),
#              ('antidiscrimin',
#               {'46782188': [1, [1495]],
#                46782188: [1, array([1495], dtype=int64)]}),
#              ('antidowri',
#               {'46782188': [1, [416]],
#                46782188: [1, array([416], dtype=int64)]}),
#              ('antidrug',
#               {'46782188': [1, [1181]],
#                46782188: [1, array([1181], dtype=int64)]}),
#              ('antiethn',
#               {'46782188': [1, [1531]],
#                46782188: [1, array([1531], dtype=int64)]}),
#              ('antihomeless',
#               {'46782188': [1, [1180]],
#                46782188: [1, array([1180], dtype=int64)]}),
#              ('antiintellectu',
#               {'46782188': [1, [1183]],
#                46782188: [1, array([1183], dtype=int64)]}),
#              ('antiintersex',
#               {'46782188': [1, [1184]],
#                46782188: [1, array([1184], dtype=int64)]}),
#              ('antileft',
#               {'46782188': [1, [1185]],
#                46782188: [1, array([1185], dtype=int64)]}),
#              ('antimalari',
#               {'6335141': [1, [191]],
#                6335141: [1, array([191], dtype=int64)]}),
#              ('antimasonri',
#               {'46782188': [1, [1187]],
#                46782188: [1, array([1187], dtype=int64)]}),
#              ('antimicrobi',
#               {'6335141': [3, [275, 293, 407]],
#                6335141: [3, array([275, 293, 407], dtype=int64)]}),
#              ('antimuslim',
#               {'46782188': [1, [329]],
#                46782188: [1, array([329], dtype=int64)]}),
#              ('antin',
#               {'46782188': [2, [318, 1530]],
#                46782188: [2, array([ 318, 1530], dtype=int64)]}),
#              ('antiport',
#               {'6335141': [1, [157]],
#                6335141: [1, array([157], dtype=int64)]}),
#              ('antiqu',
#               {'197982': [1, [810]], 406512: [1, array([7372], dtype=int64)]}),
#              ('antireligi', {'406512': [1, [1168]]}),
#              ('antisemit',
#               {'46782188': [1, [1188]],
#                46782188: [1, array([1188], dtype=int64)]}),
#              ('antitrust',
#               {'1290848': [1, [1168]],
#                1290848: [1, array([1168], dtype=int64)]}),
#              ('antler', {'554919': [1, [2766]]}),
#              ('antoin', {'12211231': [1, [338]]}),
#              ('antonio',
#               {'706315': [1, [661]],
#                706315: [1, array([661], dtype=int64)],
#                1872229: [1, array([3134], dtype=int64)]}),
#              ('antsi',
#               {'7035425': [1, [2607]],
#                7035425: [1, array([2607], dtype=int64)]}),
#              ('antwerp',
#               {'1872229': [1, [3094]],
#                554919: [1, array([485], dtype=int64)]}),
#              ('anu',
#               {'7035425': [1, [2068]],
#                7035425: [1, array([2068], dtype=int64)]}),
#              ('anuki',
#               {'7035425': [1, [2215]],
#                7035425: [1, array([2215], dtype=int64)]}),
#              ('anuta',
#               {'7035425': [1, [2484]],
#                7035425: [1, array([2484], dtype=int64)]}),
#              ('anuthatantrum', {'215764': [3, [334, 871, 1360]]}),
#              ('anvari', {'406512': [1, [4496]]}),
#              ('anyth', {'60262322': [1, [794]]}),
#              ('aoheng',
#               {'7035425': [1, [1399]],
#                7035425: [1, array([1399], dtype=int64)]}),
#              ('aol',
#               {'1290848': [1, [2555]],
#                1290848: [1, array([2555], dtype=int64)]}),
#              ('aore',
#               {'7035425': [1, [2277]],
#                7035425: [1, array([2277], dtype=int64)]}),
#              ('apalik',
#               {'7035425': [1, [2152]],
#                7035425: [1, array([2152], dtype=int64)]}),
#              ('apartheid',
#               {'46782188': [1, [1427]],
#                46782188: [1, array([1427], dtype=int64)]}),
#              ('apat',
#               {'7035425': [4, [458, 502, 517, 531]],
#                7035425: [4, array([458, 502, 517, 531], dtype=int64)]}),
#              ('ape',
#               {'7035425': [1, [1718]],
#                7035425: [1, array([1718], dtype=int64)]}),
#              ('api',
#               {'7035425': [1, [1533]],
#                7035425: [1, array([1533], dtype=int64)]}),
#              ('apia', {'13268827': [2, [297, 663]]}),
#              ('apma',
#               {'7035425': [1, [2260]],
#                7035425: [1, array([2260], dtype=int64)]}),
#              ('apoi',
#               {'7035425': [4, [451, 466, 482, 511]],
#                7035425: [4, array([451, 466, 482, 511], dtype=int64)]}),
#              ('apollo', {'215764': [1, [921]]}),
#              ('aporophobia',
#               {'46782188': [1, [1189]],
#                46782188: [1, array([1189], dtype=int64)]}),
#              ('apostol', {'215764': [1, [201]]}),
#              ('appar',
#               {'73423': [1, [732]], 1065834: [1, array([996], dtype=int64)]}),
#              ('apparent',
#               {'1290848': [1, [1837]],
#                1290848: [1, array([1837], dtype=int64)]}),
#              ('appeal', {'215764': [1, [495]]}),
#              ('appearanc',
#               {'1512303': [1, [1842]],
#                6335141: [1, array([54], dtype=int64)],
#                1512303: [1, array([1842], dtype=int64)]}),
#              ('appendix', {'60262322': [1, [637]]}),
#              ('apple',
#               {'1512303': [1, [45]],
#                1512303: [1, array([45], dtype=int64)],
#                1065834: [1, array([1779], dtype=int64)]}),
#              ('appli',
#               {'593630': [2, [46, 72]],
#                150035: [6, array([  7,  24,  30, 131, 205, 213], dtype=int64)],
#                554919: [1, array([2860], dtype=int64)],
#                197982: [1, array([64], dtype=int64)],
#                55901869: [1, array([320], dtype=int64)]}),
#              ('applic',
#               {'6335141': [1, [457]],
#                6335141: [1, array([457], dtype=int64)],
#                649708: [1, array([59], dtype=int64)],
#                6131861: [1, array([109], dtype=int64)],
#                197982: [1, array([271], dtype=int64)],
#                55901869: [2, array([365, 566], dtype=int64)]}),
#              ('applicat',
#               {'6335141': [1, [473]],
#                6335141: [1, array([473], dtype=int64)],
#                593630: [1, array([1627], dtype=int64)],
#                215764: [1, array([1398], dtype=int64)]}),
#              ('appoint',
#               {'1168659': [3, [88, 138, 145]],
#                1290848: [2, array([2103, 2131], dtype=int64)],
#                1168659: [3, array([ 88, 138, 145], dtype=int64)],
#                406512: [1, array([3162], dtype=int64)],
#                55901869: [2, array([ 81, 214], dtype=int64)]}),
#              ('appoints',
#               {'1290848': [1, [2179]],
#                1290848: [1, array([2179], dtype=int64)]}),
#              ('appreci',
#               {'46782188': [1, [493]],
#                46782188: [1, array([493], dtype=int64)]}),
#              ('approach',
#               {'6335141': [1, [171]],
#                46782188: [1, array([123], dtype=int64)],
#                6335141: [1, array([171], dtype=int64)],
#                73423: [1, array([594], dtype=int64)],
#                707912: [1, array([689], dtype=int64)],
#                60262322: [1, array([551], dtype=int64)]}),
#              ('appropri', {'42663952': [1, [116]]}),
#              ('approv', {'406512': [1, [1358]]}),
#              ('approxim',
#               {'1512303': [1, [834]],
#                1290848: [1, array([1446], dtype=int64)],
#                7035425: [1, array([144], dtype=int64)],
#                1512303: [1, array([834], dtype=int64)],
#                1872229: [1, array([504], dtype=int64)],
#                406512: [1, array([4212], dtype=int64)]}),
#              ('apr', {'406512': [1, [1579]]}),
#              ('april',
#               {'1512303': [4, [905, 2112, 2373, 2458]],
#                1290848: [9,
#                 array([ 845,  901, 1158, 1215, 2321, 2389, 2408, 2411, 2429], dtype=int64)],
#                1512303: [4, array([ 905, 2112, 2373, 2458], dtype=int64)],
#                215764: [8,
#                 array([  44,   90,  168, 1144, 1150, 1241, 1324, 1334], dtype=int64)],
#                707912: [2, array([ 557, 1210], dtype=int64)],
#                1872229: [1, array([2820], dtype=int64)],
#                1065834: [1, array([1734], dtype=int64)],
#                60262322: [1, array([590], dtype=int64)],
#                13268827: [38,
#                 array([1145, 1157, 1172, 1185, 1201, 1214, 1224, 1236, 1250, 1257, 1261,
#                        1270, 1274, 1287, 1302, 1316, 1331, 1344, 1355, 1371, 1386, 1401,
#                        1415, 1427, 1440, 1456, 1467, 1479, 1494, 1507, 1522, 1535, 1548,
#                        1564, 1575, 1579, 1588, 1592], dtype=int64)],
#                406512: [15,
#                 array([3536, 4574, 4613, 5406, 5527, 5544, 5561, 5579, 5596, 5613, 5630,
#                        5649, 5665, 5683, 5931], dtype=int64)],
#                55901869: [1, array([603], dtype=int64)]}),
#              ('aprilmai', {'554919': [1, [677]]}),
#              ('apta', {'554919': [1, [349]]}),
#              ('apu', {'593630': [5, [1116, 1127, 1166, 1211, 1228]]}),
#              ('apui',
#               {'7035425': [1, [497]],
#                7035425: [1, array([497], dtype=int64)]}),
#              ('aput',
#               {'7035425': [1, [1400]],
#                7035425: [1, array([1400], dtype=int64)]}),
#              ('aqanj', {'406512': [1, [7006]]}),
#              ('ara', {'406512': [1, [3702]]}),
#              ('arab',
#               {'46782188': [2, [1260, 1654]],
#                46782188: [2, array([1260, 1654], dtype=int64)],
#                406512: [5,
#                 array([ 439, 1702, 2706, 5271, 6908], dtype=int64)]}),
#              ('arabha', {'406512': [1, [6619]]}),
#              ('arabia',
#               {'46782188': [1, [1644]],
#                46782188: [1, array([1644], dtype=int64)],
#                406512: [1, array([5176], dtype=int64)]}),
#              ('arabian', {'406512': [3, [1686, 1690, 6159]]}),
#              ('arabic',
#               {'7035425': [1, [2720]],
#                7035425: [1, array([2720], dtype=int64)],
#                406512: [1, array([336], dtype=int64)]}),
#              ('arak', {'406512': [2, [7171, 7268]]}),
#              ('araki',
#               {'7035425': [1, [2271]],
#                7035425: [1, array([2271], dtype=int64)]}),
#              ('aralletabulahan',
#               {'7035425': [1, [1643]],
#                7035425: [1, array([1643], dtype=int64)]}),
#              ('araw',
#               {'7035425': [1, [507]],
#                7035425: [1, array([507], dtype=int64)]}),
#              ('arbab', {'406512': [1, [6402]]}),
#              ('arc',
#               {'2438495': [1, [319]],
#                2438495: [1, array([319], dtype=int64)]}),
#              ('arcad',
#               {'1512303': [1, [1651]],
#                1512303: [1, array([1651], dtype=int64)]}),
#              ('arcade',
#               {'1512303': [1, [1216]],
#                1512303: [1, array([1216], dtype=int64)]}),
#              ('arch',
#               {'2438495': [1, [200]],
#                2438495: [1, array([200], dtype=int64)]}),
#              ('archaeolog', {'554919': [2, [2522, 2739]]}),
#              ('archaeologi',
#               {'46782188': [1, [1040]],
#                46782188: [1, array([1040], dtype=int64)],
#                554919: [1, array([2524], dtype=int64)]}),
#              ('archipelago',
#               {'2438495': [1, [149]],
#                2438495: [1, array([149], dtype=int64)]}),
#              ...])
